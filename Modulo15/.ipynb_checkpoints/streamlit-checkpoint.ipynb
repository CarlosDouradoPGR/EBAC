# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("bikes_data.csv")

# %%
# Renomeando as colunas para termos mais fáceis de manusear
df.columns = ["montadora", "pais", "modelo","cilindrada" ,"potencia(hp)", "torque(N/m)", "tipo_transmissao", "modelo_transmissao", "assentos", "preco_irn", "anos", "aparencia", "tipo_corpo", "tipo_motor", "numero_cilindros"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362 entries, 0 to 361
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   montadora           362 non-null    object
#  1   pais                362 non-null    object
#  2   modelo              362 non-null    object
#  3   cilindrada          362 non-null    object
#  4   potencia(hp)        362 non-null    object
#  5   torque(N/m)         362 non-null    object
#  6   tipo_transmissao    362 non-null    object
#  7   modelo_transmissao  362 non-null    object
#  8   assentos            362 non-null    int64
#  9   preco_irn           362 non-null    object
#  10  anos                362 non-null    int64
#  11  aparencia           362 non-null    object
#  12  tipo_corpo          362 non-null    object
#  13  tipo_motor          362 non-null    object
#  14  numero_cilindros    361 non-null    object
# dtypes: int64(2), object(13)
# memory usage: 42.6+ KB

# %%
df["cilindrada"] = df["cilindrada"].str.replace(" kW", "")
df["cilindrada"] = df["cilindrada"].str.replace("cc", "")
df["cilindrada"] = df["cilindrada"].str.replace("Electric", "0")
df["cilindrada"] = df["cilindrada"].str.replace(",", "")
df["cilindrada"] = df["cilindrada"].astype(float)

# %%
fig, axes = plt.subplots(figsize=(20,7))

sns.countplot(x=sorted(df["pais"]))
plt.xticks(rotation=45)
plt.show()

# %%
# Quais montadoras tem motos acima de 600 cilindadas?
df[df['cilindrada'] >= 600]
# Out:
#        montadora   pais           modelo  cilindrada         potencia(hp)  \
# 0        Aprilia  Italy           RS 660       659.0               100 hp
# 1        Aprilia  Italy        Tuono 660       659.0               100 hp
# 3        Aprilia  Italy       Shiver 900       896.0                95 hp
# 4        Aprilia  Italy       Tuono 1100      1077.0               175 hp
# 8        Benelli  Italy         TNT 600i       600.0                85 hp
# ..           ...    ...              ...         ...                  ...
# 324  Royal Alloy     UK  Interceptor 650       649.0  47.6 PS @ 7,250 rpm
# 333      Benelli  Italy         TNT 600i       600.0   85 hp @ 11,000 rpm
# 336      Benelli  Italy        TNT 600RR       600.0  118 hp @ 11,500 rpm
# 360  Moto Morini  Italy           X-Cape       649.0              60.8 PS
# 361  Moto Morini  Italy   Seiemmezzo 6 ½       649.0              55.7 PS
#
#             torque(N/m)      tipo_transmissao modelo_transmissao  assentos  \
# 0                 67 Nm  6-speed quickshifter              Chain         2
# 1                 67 Nm  6-speed quickshifter              Chain         2
# 3                 90 Nm        6-speed manual              Shaft         2
# 4                121 Nm        6-speed manual              Shaft         2
# 8               54.6 Nm                Manual              Chain         2
# ..                  ...                   ...                ...       ...
# 324   52 Nm @ 5,250 rpm        6-speed manual        Chain drive         2
# 333    54 Nm @ 8000 rpm        6-speed manual        Chain drive         2
# 336  66 Nm @ 10,500 rpm        6-speed manual        Chain drive         2
# 360               62 Nm        6-speed manual      Parallel twin         2
# 361               58 Nm        6-speed manual      Parallel twin         2
#
#          preco_irn  anos  aparencia         tipo_corpo  \
# 0    INR 10,99,000  2021      Sport              Naked
# 1    INR 11,99,000  2021      Sport              Naked
# 3    INR 13,99,000  2022  Adventure              Naked
# 4    INR 19,99,000  2022  Adventure              Naked
# 8         4,00,000  2023     Sporty              Sport
# ..             ...   ...        ...                ...
# 324       4.5 Lakh  2023    Classic            Cruiser
# 333   Rs. 6,19,000  2018      Sport         Supersport
# 336   Rs. 7,50,000  2022      Sport         Supersport
# 360       7,20,000  2023     Modern  Adventure touring
# 361       6,89,000  2023      Retro              Naked
#
#                        tipo_motor numero_cilindros
# 0                   Parallel-twin                2
# 1                   Parallel-twin                2
# 3                          V-twin                2
# 4                          V-twin                2
# 8                   Parallel-twin                2
# ..                            ...              ...
# 324                    Air-Cooled    Parallel-Twin
# 333  Parallel-twin, liquid-cooled              Two
# 336  Parallel-twin, liquid-cooled              Two
# 360           Liquid-cooled, DOHC                2
# 361           Liquid-cooled, DOHC                2
#
# [108 rows x 15 columns]

# %%
montadora = df["montadora"].unique()

# %%
df[df["montadora"] == "Aprilia"]
# Out:
#   montadora   pais      modelo  cilindrada potencia(hp) torque(N/m)  \
# 0   Aprilia  Italy      RS 660       659.0       100 hp       67 Nm
# 1   Aprilia  Italy   Tuono 660       659.0       100 hp       67 Nm
# 2   Aprilia  Italy      RS 125       124.9        15 hp       12 Nm
# 3   Aprilia  Italy  Shiver 900       896.0        95 hp       90 Nm
# 4   Aprilia  Italy  Tuono 1100      1077.0       175 hp      121 Nm
#
#        tipo_transmissao modelo_transmissao  assentos      preco_irn  anos  \
# 0  6-speed quickshifter              Chain         2  INR 10,99,000  2021
# 1  6-speed quickshifter              Chain         2  INR 11,99,000  2021
# 2        6-speed manual              Chain         2   INR 4,49,000  2022
# 3        6-speed manual              Shaft         2  INR 13,99,000  2022
# 4        6-speed manual              Shaft         2  INR 19,99,000  2022
#
#    aparencia tipo_corpo       tipo_motor numero_cilindros
# 0      Sport      Naked    Parallel-twin                2
# 1      Sport      Naked    Parallel-twin                2
# 2      Sport     Racing  Single-cylinder                1
# 3  Adventure      Naked           V-twin                2
# 4  Adventure      Naked           V-twin                2

# %%
df[(df["montadora"] == "Aprilia") & (df["cilindrada"] >500)]
# Out:
#   montadora   pais      modelo  cilindrada potencia(hp) torque(N/m)  \
# 0   Aprilia  Italy      RS 660       659.0       100 hp       67 Nm
# 1   Aprilia  Italy   Tuono 660       659.0       100 hp       67 Nm
# 3   Aprilia  Italy  Shiver 900       896.0        95 hp       90 Nm
# 4   Aprilia  Italy  Tuono 1100      1077.0       175 hp      121 Nm
#
#        tipo_transmissao modelo_transmissao  assentos      preco_irn  anos  \
# 0  6-speed quickshifter              Chain         2  INR 10,99,000  2021
# 1  6-speed quickshifter              Chain         2  INR 11,99,000  2021
# 3        6-speed manual              Shaft         2  INR 13,99,000  2022
# 4        6-speed manual              Shaft         2  INR 19,99,000  2022
#
#    aparencia tipo_corpo     tipo_motor numero_cilindros
# 0      Sport      Naked  Parallel-twin                2
# 1      Sport      Naked  Parallel-twin                2
# 3  Adventure      Naked         V-twin                2
# 4  Adventure      Naked         V-twin                2

# %%
df["tipo_corpo"].unique()
# Out:
# array(['Naked', 'Racing', 'Sport', 'Adventure', 'Cruiser', 'Roadster',
#        'Superbike', 'Cafe Racer', 'Bobber', 'Scrambler', 'Sportbike',
#        'Adventure touring', 'Supermoto', 'Sport-touring', 'Fighter',
#        'Scooter', 'Sports', 'Standard', 'Tourer', 'Enduro', 'Supersport',
#        'Sport touring', 'Cafe racer', 'Café racer', 'Sports bike',
#        'Adventure bike', 'Naked bike', 'Street bike', 'Maxi-Scooter',
#        'Naked Bike', 'Retro', 'Dual-sport', 'Motocross', 'Trail',
#        'Naked streetfighter', 'Street', 'Street naked', 'commuter',
#        'Mountain bike', 'Hybrid bike', 'Electric scooter',
#        'Mountain Bike', 'Street Bike', 'Streetfighter', 'Touring',
#        'Sports Naked', 'Commuter', 'Dirt bike', 'Off-road', 'Cargo',
#        'Classic', 'Bicycle', 'Trail Bike', 'Adventure tourer',
#        'Street scrambler', 'Tracker'], dtype=object)

# %%
df[(df["tipo_corpo"] == "Sport")]
# Out:
#   montadora   pais  modelo  cilindrada potencia(hp) torque(N/m)  \
# 2   Aprilia  Italy  RS 125       124.9        15 hp       12 Nm
#
#   tipo_transmissao modelo_transmissao  assentos     preco_irn  anos aparencia  \
# 2   6-speed manual              Chain         2  INR 4,49,000  2022     Sport
#
#   tipo_corpo       tipo_motor numero_cilindros
# 2     Racing  Single-cylinder                1
